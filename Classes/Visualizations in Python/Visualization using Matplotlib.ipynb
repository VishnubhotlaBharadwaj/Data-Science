# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = [-3,5,7]
y = [10,2,5]

# %%
fig = plt.figure(figsize = (15,3))
plt.plot(x,y)
plt.xlim(-4,10)
plt.ylim(-3,12)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line plot')
plt.suptitle('Sales comparision', size=20, y=1.03)
# Out:
# Text(0.5, 1.03, 'Sales comparision')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

mtcars = pd.read_csv("mtcars.csv")

# %%
mtcars.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
mtcars.shape
# Out:
# (32, 11)

# %%
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
pd.crosstab(mtcars.gear, mtcars.cyl)
# Out:
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2

# %%
pd.crosstab(mtcars.gear, mtcars.cyl).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='gear'>

# %%
mtcars["gear"].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
mtcars["gear"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='gear'>

# %%
import seaborn as sns

# %%
sns.boxplot(x="gear", y="mpg", data=mtcars)
# Out:
# <AxesSubplot:xlabel='gear', ylabel='mpg'>

# %%
sns.pairplot(mtcars.iloc[:,0:4])

# %%
sns.pairplot(mtcars)

# %%
plt.scatter(mtcars.mpg,mtcars.qsec)

# %%
plt.hist(mtcars['mpg'])
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtcars['mpg'],facecolor='peru',edgecolor='blue',bins=5)
# Out:
# (array([ 6., 12.,  8.,  2.,  4.]),
#  array([10.4, 15.1, 19.8, 24.5, 29.2, 33.9]),
#  <BarContainer object of 5 artists>)

# %%
plt.boxplot(mtcars['mpg'],vert = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x244c55e66a0>,
#   <matplotlib.lines.Line2D at 0x244c55e6a00>],
#  'caps': [<matplotlib.lines.Line2D at 0x244c55e6d60>,
#   <matplotlib.lines.Line2D at 0x244c55f2100>],
#  'boxes': [<matplotlib.lines.Line2D at 0x244c55e6340>],
#  'medians': [<matplotlib.lines.Line2D at 0x244c55f2460>],
#  'fliers': [<matplotlib.lines.Line2D at 0x244c55f27c0>],
#  'means': []}

# %%
plt.boxplot(mtcars['mpg'],vert =False);
plt.ylabel("MPG");
plt.xlabel("Boxplot");
plt.title("Boxplot")
# Out:
# Text(0.5, 1.0, 'Boxplot')

# %%
plt.violinplot(mtcars["mpg"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x244c444d070>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x244c4445d30>,
#  'cmins': <matplotlib.collections.LineCollection at 0x244c4445ee0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x244c44548b0>}

# %%
import pandas as pd
df = pd.DataFrame(index=['Atiya', 'Abbas', 'Cornelia','Stephanie', 'Monte'],
                   data={'Apples':[20, 10, 40, 20, 50],'Oranges':[35, 40, 25, 19, 33]})

# %%
ax = df.plot.bar(color=['.7','.3'], figsize=(16,4))

# %%
ax = df.plot.kde(color=['.2',".7"], figsize=(16,4))

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))
fig.suptitle('Two Variable Plots')
df.plot.line(ax=ax1, title='Line plot')
df.plot.scatter(x='Apples', y='Oranges',ax=ax2, title='Scatterplot')
df.plot.bar(ax=ax3, title='Bar plot')
# Out:
# <AxesSubplot:title={'center':'Bar plot'}>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))
fig.suptitle('One Variable Plots', size=20, y=1.02)
df.plot.kde(ax=ax1, title='KDE plot')
df.plot.box(ax=ax2, title='Boxplot')
df.plot.hist(ax=ax3, title='Histogram')
# Out:
# <AxesSubplot:title={'center':'Histogram'}, ylabel='Frequency'>
